# %% [markdown]
# <a href="https://colab.research.google.com/github/AmritKalmane20/Python-Work/blob/main/Pandas_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![series-and-dataframe.width-1200.png](attachment:series-and-dataframe.width-1200.png)

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.4)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.25.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %% [markdown]
# ## Series

# %%
## Creating empty series
d=pd.Series(dtype= float)
d
# Out:
# Series([], dtype: float64)

# %%
type(d)
# Out:
# pandas.core.series.Series

# %%
## Creating series with one element
d=pd.Series(17)

# %%
d
# Out:
# 0    17
# dtype: int64

# %%
## Creating series using tuple
t=(10,11,12)
d=pd.Series(t)

# %%
d
# Out:
# 0    10
# 1    11
# 2    12
# dtype: int64

# %%
##  creating series using list
d=pd.Series([45,78,56,44.5,78])

# %%
d
# Out:
# 0    45.0
# 1    78.0
# 2    56.0
# 3    44.5
# 4    78.0
# dtype: float64

# %%
## Creating series with array
import numpy as np
arr=np.array([1,2,3.7,4])
d1=pd.Series(arr)
d1
# Out:
# 0    1.0
# 1    2.0
# 2    3.7
# 3    4.0
# dtype: float64

# %%
# Extract 3.7 from variable d1
d1[2]
# Out:
# 3.7

# %%
arr2= np.array([[1,2],[3,4],[5,6]])
arr2.shape
# Out:
# (3, 2)

# %%
arr2
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])

# %%
s2 = pd.Series()
# Out:
# <ipython-input-16-f42458fe92b3>:1: FutureWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   s2 = pd.Series()

# %%
## Using dictionary
d={'ab':1,'b1':2,'c':3,'d':4}
d
# Out:
# {'ab': 1, 'b1': 2, 'c': 3, 'd': 4}

# %%
d.values() #To see the Values of a Dictionary
# Out:
# dict_values([1, 2, 3, 4])

# %%
d.keys() #To see the Keys of a Dictionary
# Out:
# dict_keys(['ab', 'b1', 'c', 'd'])

# %%
b=pd.Series(d)
b
# Out:
# ab    1
# b1    2
# c     3
# d     4
# dtype: int64

# %%
#Extracting elements out from a series
#b["d"]
b[3]
# Out:
# 4

# %%
d=pd.Series([1,2,3,5,47,98,7,8,6,32,78,2,8,289,258,78])
d
# Out:
# 0       1
# 1       2
# 2       3
# 3       5
# 4      47
# 5      98
# 6       7
# 7       8
# 8       6
# 9      32
# 10     78
# 11      2
# 12      8
# 13    289
# 14    258
# 15     78
# dtype: int64

# %%
#Task: Extract 47,289,78,1,47
d[[4,13,15,0,4]] #Multiple index
# Out:
# 4      47
# 13    289
# 15     78
# 0       1
# 4      47
# dtype: int64

# %%
## Slicing operation
d[5:11]
# Out:
# 5     98
# 6      7
# 7      8
# 8      6
# 9     32
# 10    78
# dtype: int64

# %%
d[1]=100  ## changing the element

# %%
d
# Out:
# 0       1
# 1     100
# 2       3
# 3       5
# 4      47
# 5      98
# 6       7
# 7       8
# 8       6
# 9      32
# 10     78
# 11      2
# 12      8
# 13    289
# 14    258
# 15     78
# dtype: int64

# %%
d[6:10]=[100,200,300,400] # 6,7,8,9

# %%
d
# Out:
# 0       1
# 1     100
# 2       3
# 3       5
# 4      47
# 5      98
# 6     100
# 7     200
# 8     300
# 9     400
# 10     78
# 11      2
# 12      8
# 13    289
# 14    258
# 15     78
# dtype: int64

# %%
arr3=np.array([1,2,4.2,"Six"])
s=pd.Series(arr3,index=['one','Two','Three','Four'])
s
# Out:
# one        1
# Two        2
# Three    4.2
# Four     Six
# dtype: object

# %%
#Checking the datatype of variable
type(s)
# Out:
# pandas.core.series.Series

# %%
#Checking the datatype of elements
s.dtype
# Out:
# dtype('O')

# %% [markdown]
# ## DataFrame

# %%
## empty dataframe Ex: matrix
d=pd.DataFrame()
d
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
type(d)
# Out:
# pandas.core.frame.DataFrame

# %%
data=[['abc',1],['def',2],['ghi',3],['hij'],['klm','a']]

# %%
data
# Out:
# [['abc', 1], ['def', 2], ['ghi', 3], ['hij'], ['klm', 'a']]

# %%
d=pd.DataFrame(data)
d
# Out:
#      0     1
# 0  abc     1
# 1  def     2
# 2  ghi     3
# 3  hij  None
# 4  klm     a

# %%
d=pd.DataFrame(data,columns=['Name','Roll Number']) ## changing the column
d
# Out:
#   Name Roll Number
# 0  abc           1
# 1  def           2
# 2  ghi           3
# 3  hij        None
# 4  klm           a

# %%
d=pd.DataFrame(data,columns=['A','B'],index=['A','B','C','D','E'])  ## changing the index
d
# Out:
#      A     B
# A  abc     1
# B  def     2
# C  ghi     3
# D  hij  None
# E  klm     a

# %%
## dataframe using dictonary
data={'Name':['a','b','c','d','e','f'],'Age':[45,12,48,25,12,56]}
print(type(data))
data
# Out:
# <class 'dict'>
# {'Name': ['a', 'b', 'c', 'd', 'e', 'f'], 'Age': [45, 12, 48, 25, 12, 56]}

# %%
d=pd.DataFrame(data,index=['A','B','C','D','E','F'])
d
# Out:
#   Name  Age
# A    a   45
# B    b   12
# C    c   48
# D    d   25
# E    e   12
# F    f   56

# %%
d.rename({'Name':'Candidate','Age':'Age_in_years'},axis=1,inplace=True)

# %%
d
# Out:
#   Candidate  Age_in_years
# A         a            45
# B         b            12
# C         c            48
# D         d            25
# E         e            12
# F         f            56

# %%
## Accessing the elements from dataframe
data=[['Alex',10,'Maths'],['Bob',12,'Science'],['Kelly',15,'Eco'],
      ['Boris',14,'Geo'],['Ken',18,'English']]
data
# Out:
# [['Alex', 10, 'Maths'],
#  ['Bob', 12, 'Science'],
#  ['Kelly', 15, 'Eco'],
#  ['Boris', 14, 'Geo'],
#  ['Ken', 18, 'English']]

# %%
d=pd.DataFrame(data,columns=['Name','Age','Subject'])

# %%
d
# Out:
#     Name  Age  Subject
# 0   Alex   10    Maths
# 1    Bob   12  Science
# 2  Kelly   15      Eco
# 3  Boris   14      Geo
# 4    Ken   18  English

# %%
## accessing one single column
d['Subject'] #d.Name  #Its a Series
# Out:
# 0      Maths
# 1    Science
# 2        Eco
# 3        Geo
# 4    English
# Name: Subject, dtype: object

# %%
## accessing Multiple column
#Extract: Subject,Name,Age
d[["Subject","Age","Name"]]
# Out:
#    Subject  Age   Name
# 0    Maths   10   Alex
# 1  Science   12    Bob
# 2      Eco   15  Kelly
# 3      Geo   14  Boris
# 4  English   18    Ken

# %%
d
# Out:
#     Name  Age  Subject
# 0   Alex   10    Maths
# 1    Bob   12  Science
# 2  Kelly   15      Eco
# 3  Boris   14      Geo
# 4    Ken   18  English

# %%
d.iloc[[2],0:]
# Out:
#     Name  Age Subject
# 2  Kelly   15     Eco

# %%
d.shape
# Out:
# (5, 3)

# %%
d.iloc[[1,3],[0,1]]
# Out:
#     Name  Age
# 1    Bob   12
# 3  Boris   14

# %%
d.iloc[2,2]='Ecology'

# %%
d
# Out:
#     Name  Age  Subject
# 0   Alex   10    Maths
# 1    Bob   12  Science
# 2  Kelly   15  Ecology
# 3  Boris   14      Geo
# 4    Ken   18  English

# %%
d.iloc[0,0] ="ALAN"  # changing an element

# %%
d
# Out:
#     Name  Age  Subject
# 0   ALAN   10    Maths
# 1    Bob   12  Science
# 2  Kelly   15  Ecology
# 3  Boris   14      Geo
# 4    Ken   18  English

# %%
d['Gender'] = "Male"  # initialize and add a new column to the DataFrame

# %%
d
# Out:
#     Name  Age  Subject Gender
# 0   ALAN   10    Maths   Male
# 1    Bob   12  Science   Male
# 2  Kelly   15  Ecology   Male
# 3  Boris   14      Geo   Male
# 4    Ken   18  English   Male

# %%
d['Age'] = d['Age'] - 1   # d['Age']-=1
d
# Out:
#     Name  Age  Subject Gender
# 0   ALAN    9    Maths   Male
# 1    Bob   11  Science   Male
# 2  Kelly   14  Ecology   Male
# 3  Boris   13      Geo   Male
# 4    Ken   17  English   Male

# %%
d.iloc[:,[0,1]] # Index location
# Out:
#     Name  Age
# 0   ALAN    9
# 1    Bob   11
# 2  Kelly   14
# 3  Boris   13
# 4    Ken   17

# %%
d.iloc[[3,1],[1,0]]  # [row,col]
# Out:
#    Age   Name
# 3   13  Boris
# 1   11    Bob

# %%
d.iloc[1:3,[1,0]]
# Out:
#    Age   Name
# 1   11    Bob
# 2   14  Kelly

# %%
d.iloc[[0]]  # access row 1
# Out:
#    Name  Age Subject Gender
# 0  ALAN    9   Maths   Male

# %%
d.iloc[[0],:]
# Out:
#    Name  Age Subject Gender
# 0  ALAN    9   Maths   Male

# %%
pwd
# Out:
# '/content'

# %%
d
# Out:
#     Name  Age  Subject Gender
# 0   ALAN    9    Maths   Male
# 1    Bob   11  Science   Male
# 2  Kelly   14  Ecology   Male
# 3  Boris   13      Geo   Male
# 4    Ken   17  English   Male

# %%
## to acces the single element we use iloc it will always work with index
d.iloc[1,2] ## index of row ,columns
# Out:
# 'Science'

# %% [markdown]
# loc used for locating with column names

# %%
d
# Out:
#     Name  Age  Subject Gender
# 0   ALAN    9    Maths   Male
# 1    Bob   11  Science   Male
# 2  Kelly   14  Ecology   Male
# 3  Boris   13      Geo   Male
# 4    Ken   17  English   Male

# %%
## loc will work on rows as well as names of columns
d.loc[0:1,['Name']]
# Out:
#    Name
# 0  ALAN
# 1   Bob

# %%
# Modify multiple values
d.iloc[:2,0]= ['JKL','ABC']  #  [0,0]   , [1,0],

# %%
d
# Out:
#     Name  Age  Subject Gender
# 0    JKL    9    Maths   Male
# 1    ABC   11  Science   Male
# 2  Kelly   14  Ecology   Male
# 3  Boris   13      Geo   Male
# 4    Ken   17  English   Male

# %%
# Task: make kelly and xyz gender to Female.
d.iloc[1:3,[3]]='Female' # 1,2

# %%
d
# loc is typically used for accessing columns.
# Out:
#     Name  Age  Subject  Gender
# 0    JKL    9    Maths    Male
# 1    ABC   11  Science  Female
# 2  Kelly   14  Ecology  Female
# 3  Boris   13      Geo    Male
# 4    Ken   17  English    Male

# %%
d['Age']
# Out:
# 0     9
# 1    11
# 2    14
# 3    13
# 4    17
# Name: Age, dtype: int64

# %%
d.loc[:,'Age']
# Out:
# 0     9
# 1    11
# 2    14
# 3    13
# 4    17
# Name: Age, dtype: int64

# %%
d
# Out:
#     Name  Age  Subject  Gender
# 0    JKL    9    Maths    Male
# 1    ABC   11  Science  Female
# 2  Kelly   14  Ecology  Female
# 3  Boris   13      Geo    Male
# 4    Ken   17  English    Male

# %%
d.loc[0] ## getting the rows with singular index value
# Out:
# Name         JKL
# Age            9
# Subject    Maths
# Gender      Male
# Name: 0, dtype: object

# %%
d.iloc[:,[1,2]]
# Out:
#    Age  Subject
# 0    9    Maths
# 1   11  Science
# 2   14  Ecology
# 3   13      Geo
# 4   17  English

# %%
d.iloc[:3,1:3]
# Out:
#    Age  Subject
# 0    9    Maths
# 1   11  Science
# 2   14  Ecology
